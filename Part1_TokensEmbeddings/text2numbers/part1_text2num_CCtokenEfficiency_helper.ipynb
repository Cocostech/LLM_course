# %% [markdown]
# |<h2>Course:</h2>|<h1><a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">A deep understanding of AI language model mechanisms</a></h1>|
# |-|:-:|
# |<h2>Part 1:</h2>|<h1>Tokenizations and embeddings<h1>|
# |<h2>Section:</h2>|<h1>Words to tokens to numbers<h1>|
# |<h2>Lecture:</h2>|<h1><b>CodeChallenge HELPER: Token count by subword length<b></h1>|
#
# <br>
#
# <h5><b>Teacher:</b> Mike X Cohen, <a href="https://sincxpress.com" target="_blank">sincxpress.com</a></h5>
# <h5><b>Course URL:</b> <a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">udemy.com/course/dullms_x/?couponCode=202508</a></h5>
# <i>Using the code without the course may lead to confusion or errors.</i>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# !pip install tiktoken
import tiktoken
# Out:
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken) (2026.6.17)

# %%
# GPT-4's tokenizer
tokenizer = tiktoken.get_encoding('cl100k_base')

# %% [markdown]
# # Exercise 1: Token count by word length

# %%
import requests
import re
text = requests.get('https://www.gutenberg.org/files/35/35-0.txt').text
tmTokens = tokenizer.encode(text)

# %%
# split by punctuation
words = re.split(r'([,.:;—?_!"“()\']|--|\s)',text)
words = [item.strip() for item in words if item.strip()]

tokenCount = np.zeros((len(words),2),dtype=int)

for idx,w in enumerate(words):
  tokenCount[idx,0] = len(w) # first column is the length of the word
  tokenCount[idx,1] = len(tokenizer.encode(w)) # second column is the number of tokens

# %%
plt.figure(figsize=(12,4))

offsetsX = np.random.randn(len(words))/20 # appropriately scaled random scatter
offsetsY = np.random.randn(len(words))/20

plt.plot(tokenCount[:,0]+offsetsX,tokenCount[:,1]+offsetsY,'k.',alpha=.5)
plt.gca().set(xlabel='Word lengths',ylabel='Encoded token count',xticks=np.arange(1,np.max(tokenCount[:,0])+1))

plt.show()

# %% [markdown]
# # Exercise 2: Encoding of 14-character words

# %%
# find words with characters
wordsWith14Chars = set(np.where(tokenCount[:,0]==14)[0])
print(np.where(tokenCount[:,0]==14)[0])

# print their tokens
for idx in wordsWith14Chars:
  this_decode = [ tokenizer.decode([t]) for t in tokenizer.encode(words[idx]) ]# list comprehension to decode the tokens for this word
  print(f'"{idx}" comprises {this_decode}')
# Out:
# [  592   784  1204  1471  1675  1777  3084  4055  4075  4355  5045  5120
#   5244  5271  8162  9339 10525 10635 11111 11401 11773 11792 12497 17323
#  18582 18983 19416 20012 20367 20975 21153 22346 24835 25185 25487 25996
#  27508 28476 33563 33594 33811 34499 35321 37481]
# "5120" comprises ['interpret', 'ation']
# "4355" comprises ['a', 'fore', 'mentioned']
# "24835" comprises ['const', 'ell', 'ations']
# "11401" comprises ['special', 'isation']
# "1675" comprises ['Time', '-D', 'imension']
# "3084" comprises ['Psych', 'ologist', '’s']
# "10635" comprises ['con', 'vers', 'ational']
# "25996" comprises ['north', '-east', 'ward']
# "20367" comprises ['Under', 'ground', 'ers']
# "784" comprises ['math', 'ematic', 'ians']
# "11792" comprises ['interpret', 'ation']
# "25487" comprises ['disc', 'rim', 'inating']
# "33811" comprises ['mount', 'aine', 'ering']
# "18582" comprises ['ill', '-controlled']
# "5271" comprises ['Psych', 'ologist', '’s']
# "33563" comprises ['North', '-east', 'ward']
# "10525" comprises ['inter', 'rog', 'ations']
# "21153" comprises ['self', '-de', 'ception']
# "18983" comprises ['different', 'iated']
# "17323" comprises ['ex', 'post', 'ulations']
# "20012" comprises ['str', 'at', 'ification']
# "1204" comprises ['Time', '-D', 'imension']
# "5045" comprises ['wo', 'ol', '-g', 'athering']
# "33594" comprises ['south', '-east', 'ward']
# "28476" comprises ['dis', 'appointment']
# "1471" comprises ['Time', '-D', 'imension']
# "34499" comprises ['north', '-east', 'ward']
# "22346" comprises ['s', 'afety', '-m', 'atches']
# "592" comprises ['inter', 'mitt', 'ently']
# "12497" comprises ['self', '-re', 'straint']
# "4055" comprises ['potential', 'ities']
# "19416" comprises ['long', '-', 'continued']
# "25185" comprises ['const', 'ell', 'ations']
# "8162" comprises ['over', 'whelming', 'ly']
# "11111" comprises ['character', 'istic']
# "37481" comprises ['blood', '-dr', 'inking']
# "4075" comprises ['in', 'cred', 'ib', 'leness']
# "20975" comprises ['south', '-west', 'ward']
# "1777" comprises ['invest', 'ig', 'ations']
# "27508" comprises ['dis', 'incl', 'ination']
# "35321" comprises ['starting', '-point']
# "9339" comprises ['dis', 'appointment']
# "5244" comprises ['N', 'eb', 'uch', 'ad', 'ne', 'zz', 'ar']
# "11773" comprises ['interpret', 'ation']

# %% [markdown]
# # Exercise 3: Token efficiency

# %%
# "more efficient" word: lots of letters and few tokens
# "less efficient" word: few letters and many tokens
moreEfficient =
lessEfficient =

print(f'A very efficient word:\n  "{words[moreEfficient[0]]}" has {tokenCount[moreEfficient[0],0]} letters and {tokenCount[moreEfficient[0],1]} tokens.\n')
print(f'An inefficient word:\n

# %%
# "efficiency" as characters/tokens
efficiency = something / somethingElse

# show a historgram
plt.figure(figsize=(10,4))
plt.hist(efficiency,color=[.9,.7,.7],edgecolor='k',linewidth=.4,bins='fd')
plt.gca().set(xlabel=,ylabel=,title=)
plt.show()

# %%
# find the most and least efficiently tokenized words
max_efficiency =
min_efficiency =

# find all the words with those efficiency values
most_efficient_words =
least_efficient_words =

# find and print the unique words with max-efficiency score
most_efficient_words = # overwriting the previously defined variable

print('MOST EFFICIENT WORDS:')
for w in most_efficient_words:
  print(f'"{w}" has {max_efficiency} characters per token')


# repeat for min-efficiency score
print('\n\nLEAST EFFICIENT WORDS:')

# %% [markdown]
# # Exercise 4: Tokens in separated words vs. text

# %%
# unique set of words as we've split them up
uniqueWords = set(words)
print(f'There are {len(uniqueWords)} unique words in The Time Machine according to our split.')
# Out:
# There are 5006 unique words in The Time Machine according to our split.

# %%
# random token
#token_idx = np.random.randint(0,tokenizer.n_vocab//10)

# non-random tokens to try
token_idx = 1879#,5030#,716

# find the words (from our split) in The Time Machine that contain that token
words_with_token = [w for w in uniqueWords if token_idx in tokenizer.encode(w)]

# find the context (from the full encoding) surrounding each token appearance
seqs_with_token = np.array(tmTokens) == token_idx

# print the token
print(f'Token {token_idx} is "{tokenizer.decode([token_idx])}"\n\n')

# its occurance in our manually split words
print(f'*** Our manual word split: Token appears {len(words_with_token)} times, including:\n----------------')
for w in words_with_token:
    print(f'"{w}"')

# its occurances in the GPT encoding
print(f'\n\n*** From encoding the full text: This token appears {sum(seqs_with_token)} times, including:\n----------------')
for s in np.where(seqs_with_token)[0]:
    print(f'...{tokenizer.decode(tmTokens[s-5:s+5])}...')
# Out:
# Token 1879 is " sign"
#
#
# *** Our manual word split: Token appears 0 times, including:
# ----------------
#
#
# *** From encoding the full text: This token appears 2 times, including:
# ----------------
# ... from his bearing of any sign of fear struck me...
# ..., no workshops, no sign of importations among...

# %% [markdown]
# # Exercise 5: Do more frequent words have fewer tokens?

# %%
# the unique words, as a list instead of a set (for indexing)
uniqueWords = # OK to overwrite the variable...

# initialize results vectors
wordFreq = np.zeros(,dtype=int)
numTokens = np.zeros(len(uniqueWords),)


# loop through all unique words
for i,uword in enumerate(uniqueWords):

  # count the number of times that word appears


  # count the number of tokens in that word

# %%
plt.figure(figsize=(10,4))
plt.plot(
plt.gca().set(xlabel='Word frequency (log)',ylabel='Encoding length',xscale='log')
plt.show()

# %%
wordFreqidx = np.argsort(wordFreq)[::-1]
for i in wordFreqidx[:20]:
  print(f'{} appearances of "{}"')

# %% [markdown]
# # Exercise 6: Fake words from real tokens

# %%
nTokens = 3 # hmm...

# choose some random tokens
randtokens = np.random.choice(range(tokenizer.n_vocab),size=nTokens,replace=False)

# print the individual tokens
for t in randtokens:
  print(f'Token {t} is "{tokenizer.decode([t])}"')

# fake word without whitespace
fakeword = re.sub(r'^\s+|\s+$', '', ' '.join(tokenizer.decode([t]) for t in randtokens))

print(f'\nThe fake word is "{fakeword}"')
